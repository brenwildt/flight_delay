# %%
import pandas as pd

# %%
df_ = pd.read_csv('flight_delays_train.csv/flight_delays_train.csv')

# %%
df_.head()
# Out:
#   Month DayofMonth DayOfWeek  DepTime UniqueCarrier Origin Dest  Distance  \
# 0   c-8       c-21       c-7     1934            AA    ATL  DFW       732
# 1   c-4       c-20       c-3     1548            US    PIT  MCO       834
# 2   c-9        c-2       c-5     1422            XE    RDU  CLE       416
# 3  c-11       c-25       c-6     1015            OO    DEN  MEM       872
# 4  c-10        c-7       c-6     1828            WN    MDW  OMA       423
#
#   dep_delayed_15min
# 0                 N
# 1                 N
# 2                 N
# 3                 N
# 4                 Y

# %%
df_.describe()
# Out:
#              DepTime      Distance
# count  100000.000000  100000.00000
# mean     1341.523880     729.39716
# std       476.378445     574.61686
# min         1.000000      30.00000
# 25%       931.000000     317.00000
# 50%      1330.000000     575.00000
# 75%      1733.000000     957.00000
# max      2534.000000    4962.00000

# %%
for column in df_.select_dtypes(include=['object']):
    print(f"\nUnique value counts for {column}:")
    print(df_[column].value_counts())
# Out:
# Unique value counts for Month:
# Month
# c-8     8830
# c-7     8706
# c-3     8595
# c-5     8543
# c-6     8414
# c-4     8408
# c-10    8405
# c-12    8265
# c-11    8178
# c-9     8163
# c-1     8075
# c-2     7418
# Name: count, dtype: int64
#
# Unique value counts for DayofMonth:
# DayofMonth
# c-1     3399
# c-20    3380
# c-6     3377
# c-22    3374
# c-14    3366
# c-17    3347
# c-10    3342
# c-27    3330
# c-28    3321
# c-5     3321
# c-25    3314
# c-23    3314
# c-21    3312
# c-19    3305
# c-15    3297
# c-2     3285
# c-9     3283
# c-7     3272
# c-8     3258
# c-4     3249
# c-18    3246
# c-26    3241
# c-16    3240
# c-13    3238
# c-3     3228
# c-12    3212
# c-24    3210
# c-11    3168
# c-30    2976
# c-29    2837
# c-31    1958
# Name: count, dtype: int64
#
# Unique value counts for DayOfWeek:
# DayOfWeek
# c-4    14736
# c-5    14657
# c-2    14604
# c-1    14569
# c-3    14508
# c-7    14097
# c-6    12829
# Name: count, dtype: int64
#
# ...

# %%
def tweak_data(df_:pd.DataFrame) -> pd.DataFrame:
    """
    Tweak the flight delay data and return a new DataFrame.

    This function takes a Pandas DataFrame containing flight delay data as input and returns a new DataFrame.
    The modifications include extracting and transforming certain columns.

    Parameters
    -----------
    df_ : pd.DataFrame
          The input DataFrame containing the flight delay data.

    Returns
    -----------
    pd.DataFrame
          The new DataFrame with the modified columns.
    """
    return (df_
            .assign(month=df_.Month.str.slice(0,2).astype(int),
                    day_of_month=df_.DayofMonth.str.slice(0,2).astype(int),
                    day_of_week=df_.DayofWeek.str.slice(0,2).astype(int),
                    dept_time=lambda x: pd.to_datetime(x['DepTime'].astype(str).str.zfill(4), format='%H%M').dt.time)
